# %%
con={}
while True:
    ch = int(input("Enter to select operation\n1. Add contact\n2. Delete contact\n3. Update contact\n4. Show contacts\n5. Exit\n"))
    match ch:
        case 1:
            key=input("\nEnter the name:")
            value=input("Enter the number:")
            con[key]=value
            print("Contact added\n")
        case 2:
            key=input("\nEnter the name to delete:")
            if key in con:
                del con[key]
                print("\nContact deleted\n")
            else:
                print("Contact not found\n")
        case 3:
            old_key=input("\nEnter the name to update:")
            if key in con:
                new_key=input("\nEnter the new name:")
                new_value=input("\nEnter the new number:")
                con[new_key]=new_value
                del con[old_key]
                print("\nContact updated\n")
            else:
                print("Contact not found\n")
        case 4:
            print("\nnames numbers\n")
            for key, value in con.items():
                print(key,value)
        case 5:
            print("\nExiting...\n")
            break
# Out:
# Contact added
#
#
# names numbers
#
# kashi 12345
# Contact added
#
# Contact added
#
# Contact added
#
#
# names numbers
#
# kashi 12345
# aswin 23456
# ashfak 34567
# devika 45678
#
# Contact deleted
#
#
# names numbers
#
# kashi 12345
# aswin 23456
# ashfak 34567
# Contact added
#
#
# Contact updated
#
#
# names numbers
#
# aswin 23456
# ashfak 34567
# devika 45678
# Kashi 1234567890
#
# Exiting...
