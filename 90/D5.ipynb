# %%
with open("D5file.txt","r" ) as f:
    words=f.read().lower().split()
    freq={}
    for w in words:
        freq[w]=freq.get(w,0)+1
    print(freq)
# Out:
# {'python': 4, 'is': 4, 'easy': 1, 'and': 3, 'powerful': 1, 'helps': 1, 'in': 1, 'data': 2, 'science': 2, 'machine': 1, 'learning': 1, 'fun': 1, 'widely': 1, 'used': 1}
